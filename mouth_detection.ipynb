# %%
import cv2
import matplotlib.pyplot as plt
image = cv2.imread('images/face.jpg')
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

face_classifier = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_default.xml')
mouth_classifier = cv2.CascadeClassifier('haarcascades/haarcascade_msc_mouth.xml')

faces = face_classifier.detectMultiScale(gray)

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w,y+h), (127,0,255),2)
    ROI = img[y:y+h,x:x+w]
    mouth = mouth_classifier.detectMultiScale(ROI)
    for (ex,ey,ew,eh) in mouth[0:1]:
        cv2.rectangle(ROI,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img[:,:,::-1])

# %%
plt.imshow(ROI)

# %%
mouth[0:1]
# Out:
# array([[41, 93, 46, 28]])

# %%
plt.imshow(ROI[41+46:93+28, 41:93])

# %%
import math
math.sqrt()
